# %%
import pandas as pd
import numpy as np


from sklearn import preprocessing
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('C:/Users/Sohin/OneDrive/Documentos/GitHub/september-jam/World-happiness-report-updated_2024.csv', encoding='latin1')
df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.350           0.451
# 1     Afghanistan  2009        4.402               7.509           0.552
# 2     Afghanistan  2010        4.758               7.614           0.539
# 3     Afghanistan  2011        3.832               7.581           0.521
# 4     Afghanistan  2012        3.783               7.661           0.521
# ...           ...   ...          ...                 ...             ...
# 2358     Zimbabwe  2019        2.694               7.698           0.759
# 2359     Zimbabwe  2020        3.160               7.596           0.717
# 2360     Zimbabwe  2021        3.155               7.657           0.685
# 2361     Zimbabwe  2022        3.296               7.670           0.666
# 2362     Zimbabwe  2023        3.572               7.679           0.694
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df.columns = df.columns.str.lower()
df
# Out:
#      country name  year  life ladder  log gdp per capita  social support  \
# 0     Afghanistan  2008        3.724               7.350           0.451
# 1     Afghanistan  2009        4.402               7.509           0.552
# 2     Afghanistan  2010        4.758               7.614           0.539
# 3     Afghanistan  2011        3.832               7.581           0.521
# 4     Afghanistan  2012        3.783               7.661           0.521
# ...           ...   ...          ...                 ...             ...
# 2358     Zimbabwe  2019        2.694               7.698           0.759
# 2359     Zimbabwe  2020        3.160               7.596           0.717
# 2360     Zimbabwe  2021        3.155               7.657           0.685
# 2361     Zimbabwe  2022        3.296               7.670           0.666
# 2362     Zimbabwe  2023        3.572               7.679           0.694
#
#       healthy life expectancy at birth  freedom to make life choices  \
# ...

# %%
df.isna().sum()
df= df.dropna()

# %%
df.isna().sum()
# Out:
# country name                        0
# year                                0
# life ladder                         0
# log gdp per capita                  0
# social support                      0
# healthy life expectancy at birth    0
# freedom to make life choices        0
# generosity                          0
# perceptions of corruption           0
# positive affect                     0
# negative affect                     0
# dtype: int64

# %%
df = pd.get_dummies(df, columns=['country name'])

# %%
features = df.drop('life ladder', axis=1)
target = df['life ladder']

# %%
features_train, features_valid, target_train, train_valid = train_test_split(features, target, test_size=0.2, random_state=42)
features_test, features_valid, target_valid, target_test = train_test_split(features, target,test_size=0.5, random_state=42)

# %%
display(features_train.shape)
display(features_valid.shape)
display(features_test.shape)
display(target_train.shape)
display(target_valid.shape)
display(target_test.shape)
# Out:
# (1677, 164)
# (1049, 164)
# (1048, 164)
# (1677,)
# (1048,)
# (1049,)

# %%
print(df['life ladder'].dtype)
print(df['life ladder'].nunique())
# Out:
# float64
# 1644

# %%
# best_model = None
# best_result = 10
# best_est = 0
# best_depth = 0
# for est in range(1, 10, 1):
#     for depth in range (1, 5):
#         model_rtf = RandomForestRegressor(random_state=12345, n_estimators=est, max_depth=depth)
#         model_rtf.fit(features_train, target_train)
#         pred_valid = model_rtf.predict(features_valid)
#         result = mean_squared_error(target_valid, pred_valid)**0.5
#         if result < best_result:
#             best_model = model_rtf
#             best_result = result
#             best_est = est
#             best_depth = depth
# print('RMSE of the best model on the validation set:', best_result, 'n_stimators:', best_est, 'best_depth', depth)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import classification_report

model_rtf = RandomForestRegressor(random_state=12345, n_estimators=18, max_depth=20)
model_rtf.fit(features_train, target_train)
pred_valid = model_rtf.predict(features_valid)
model_rtf.score(features,target)
# Out:
# 0.9639571679680616

# %%
from sklearn.metrics import r2_score

model_lr = LinearRegression()
model_lr.fit(features_train, target_train)
pred_valid = model_lr.predict(features_valid)
model_lr.score(features,target)
# Out:
# -1.9594888847716687e+18
